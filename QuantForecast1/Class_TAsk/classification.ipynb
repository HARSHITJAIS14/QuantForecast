# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_main=pd.read_csv("/home/harshit/Desktop/QuantForecast/Class_TAsk/train.csv")

# %%
df=df_main

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# Filter numeric columns
numeric_cols =df.select_dtypes(include=['int64', 'float64']).columns

# Plotting boxplots for each numerical feature to identify outliers
for column in numeric_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[column],palette='rainbow')
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
def remove_outliers_zscore(df, features, z_score_threshold=5):
    for feature in features:
        mean_value = df[feature].mean()
        std_dev = df[feature].std()

        df[f'{feature}_z_score'] = (df[feature] - mean_value) / std_dev

        outliers = df[abs(df[f'{feature}_z_score']) > z_score_threshold]
        df = df[abs(df[f'{feature}_z_score']) <= z_score_threshold]

        print("Number of outliers removed for ",feature,":", len(outliers))
        print("Z-Score Threshold:", z_score_threshold)

    return df.drop(columns=[f'{feature}_z_score' for feature in features])

# Assuming 'df' is your DataFrame
list_of_features = df.columns.tolist()
df = remove_outliers_zscore(df, features=list_of_features, z_score_threshold=3)
df.info()
# Out:
# Number of outliers removed for  battery_power : 0
# Z-Score Threshold: 3
# Number of outliers removed for  blue : 0
# Z-Score Threshold: 3
# Number of outliers removed for  clock_speed : 0
# Z-Score Threshold: 3
# Number of outliers removed for  dual_sim : 0
# Z-Score Threshold: 3
# Number of outliers removed for  fc : 12
# Z-Score Threshold: 3
# Number of outliers removed for  four_g : 0
# Z-Score Threshold: 3
# Number of outliers removed for  int_memory : 0
# Z-Score Threshold: 3
# Number of outliers removed for  m_dep : 0
# Z-Score Threshold: 3
# Number of outliers removed for  mobile_wt : 0
# Z-Score Threshold: 3
# Number of outliers removed for  n_cores : 0
# Z-Score Threshold: 3
# Number of outliers removed for  pc : 0
# Z-Score Threshold: 3
# Number of outliers removed for  px_height : 0
# Z-Score Threshold: 3
# Number of outliers removed for  px_width : 0
# Z-Score Threshold: 3
# Number of outliers removed for  ram : 0
# Z-Score Threshold: 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1988 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1988 non-null   int64
#  1   blue           1988 non-null   int64
#  2   clock_speed    1988 non-null   float64
#  3   dual_sim       1988 non-null   int64
#  4   fc             1988 non-null   int64
#  5   four_g         1988 non-null   int64
#  6   int_memory     1988 non-null   int64
#  7   m_dep          1988 non-null   float64
#  8   mobile_wt      1988 non-null   int64
#  9   n_cores        1988 non-null   int64
#  10  pc             1988 non-null   int64
#  11  px_height      1988 non-null   int64
#  12  px_width       1988 non-null   int64
#  13  ram            1988 non-null   int64
#  14  sc_h           1988 non-null   int64
#  15  sc_w           1988 non-null   int64
#  16  talk_time      1988 non-null   int64
#  17  three_g        1988 non-null   int64
# ...

# %%
X=df.drop(columns=['price_range'])
Y=df['price_range']

# %%
# Filter numeric columns
numeric_cols =df.select_dtypes(include=['int64', 'float64']).columns

# Plotting boxplots for each numerical feature to identify outliers
for column in numeric_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[column],palette='rainbow')
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model_random=RandomForestClassifier()
model_random.fit(x_train,y_train)
y_random=model_random.predict(x_test)

# %%
# import function
from sklearn.metrics import confusion_matrix, classification_report



print(confusion_matrix(y_test,y_random))
print(classification_report(y_test,y_random))
# Out:
# [[101   5   0   0]
#  [ 11  80   9   0]
#  [  0  13  80   6]
#  [  0   0   5  88]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       106
#            1       0.82      0.80      0.81       100
#            2       0.85      0.81      0.83        99
#            3       0.94      0.95      0.94        93
#
#     accuracy                           0.88       398
#    macro avg       0.88      0.88      0.88       398
# weighted avg       0.88      0.88      0.88       398

# %% [markdown]
# ## Using PCA

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

pca = PCA(n_components=0.95, random_state=42)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

print(f"Number of components selected: {pca.n_components_}")

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_pca, y_train)
y_pred = rf.predict(X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the model with PCA-reduced features: {accuracy:.4f}")

# Step 5: Optional - Plot explained variance ratio of components
plt.figure(figsize=(10, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Number of Components')
plt.grid(True)
plt.show()
print(y_pred)
# Out:
# Number of components selected: 4
# Accuracy of the model with PCA-reduced features: 0.9121
# [0 0 0 3 0 0 1 3 2 0 2 2 0 3 0 0 2 3 1 3 2 0 2 1 3 0 0 0 1 3 2 2 1 0 2 2 1
#  3 0 0 3 2 2 1 1 3 0 2 0 0 1 3 1 0 1 0 3 0 2 3 2 2 2 1 0 2 2 3 3 0 3 0 1 1
#  3 1 1 0 3 2 0 0 2 2 2 1 0 0 3 2 3 2 1 1 1 1 0 3 0 0 3 3 0 3 1 2 2 0 2 2 0
#  1 0 3 2 0 3 1 1 1 1 3 1 3 2 0 0 0 2 2 2 0 1 3 1 1 0 3 1 0 3 1 3 3 3 2 1 2
#  1 1 1 1 0 3 2 0 3 1 1 1 3 3 3 2 3 0 2 3 3 3 2 0 1 1 2 3 2 3 2 0 0 0 1 0 1
#  0 1 3 1 1 0 3 3 0 0 2 1 2 1 1 0 1 0 2 2 1 3 3 2 0 2 0 0 3 3 1 1 1 0 3 1 2
#  1 2 0 3 2 3 3 0 3 1 3 2 3 1 3 0 2 1 2 1 1 1 2 1 2 1 3 1 1 0 3 2 3 1 1 3 0
#  1 0 3 3 3 2 2 2 1 1 0 0 3 0 2 2 3 3 1 0 2 2 2 3 3 3 0 0 2 2 0 1 0 1 1 2 3
#  2 0 1 1 1 3 2 1 2 3 0 1 3 2 1 3 3 0 3 0 0 0 1 0 0 3 1 0 0 0 0 3 3 0 3 2 1
#  2 3 3 0 2 0 1 1 0 0 1 0 0 0 3 0 2 2 0 0 0 0 2 3 2 2 2 1 0 2 0 0 2 0 2 3 0
#  2 0 0 2 2 1 2 3 1 3 1 2 1 2 0 2 0 2 2 0 3 3 2 0 0 3 3 3]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Precision: 0.9115
# Recall: 0.9121
# F1 Score: 0.9112

# %% [markdown]
# ## Using mutual_info

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
select_feature = SelectKBest(mutual_info_classif, k=3).fit(x_train, y_train)


selected_features = x_train.columns[select_feature.get_support()]

print("Selected Features:", selected_features)

x_train_2 = select_feature.transform(x_train)
x_test_2 = select_feature.transform(x_test)
clf_rf_2 = RandomForestClassifier()      
clf_rf_2.fit(x_train_2,y_train)
y_pred_info=clf_rf_2.predict(x_test_2)
ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_pred_info, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test,y_pred_info , average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_pred_info, average='weighted')))
# Out:
# Selected Features: Index(['battery_power', 'px_height', 'ram'], dtype='object')
# Accuracy is:  0.8819095477386935
# Precision: 0.8824
# Recall: 0.8819
# F1 Score: 0.8808

# %% [markdown]
# ## Using random forest importance

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=0)

clf.fit(x_train, y_train)
feature_scores = pd.Series(clf.feature_importances_, index=x_train.columns).sort_values(ascending=False)
top_4 = feature_scores.head(4).index

x_train_3=x_train[top_4]
x_test_3=x_test[top_4]
x_train_3.info()



clf = RandomForestClassifier()


clf.fit(x_train_3, y_train)


# Predict on the test set results

y_pred = clf.predict(x_test_3)

cm_3 = confusion_matrix(y_test,y_pred)
sns.heatmap(cm_3,annot=True,fmt="d")

print('Model accuracy score with top 4  variable using randomforestimportance : {0:0.4f}'. format(accuracy_score(y_test, y_pred)*100))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_pred, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test, y_pred, average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1590 entries, 809 to 1129
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ram            1590 non-null   int64
#  1   battery_power  1590 non-null   int64
#  2   px_height      1590 non-null   int64
#  3   px_width       1590 non-null   int64
# dtypes: int64(4)
# memory usage: 62.1 KB
# Model accuracy score with top 4  variable using randomforestimportance : 90.7035
# Precision: 0.9065
# Recall: 0.9070
# F1 Score: 0.9058

# %% [markdown]
# ## Applying KNN on all of it

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### PCA

# %%
knn_pca=KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca,y_train)
y_pca_knn=knn_pca.predict(X_test_pca)

# %%
print('Model accuracy score with top 4  variable using pca and knn : {0:0.4f}'. format(accuracy_score(y_test, y_pca_knn)*100))
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_pca_knn, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test, y_pca_knn, average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_pca_knn, average='weighted')))
# Out:
# Model accuracy score with top 4  variable using pca and knn : 91.9598
# Precision: 0.9192
# Recall: 0.9196
# F1 Score: 0.9190

# %% [markdown]
# ### Mutual_info

# %%
knn_info=KNeighborsClassifier(n_neighbors=5)
knn_info.fit(x_train_2,y_train)
y_info_knn=knn_info.predict(x_test_2)

# %%
print('Model accuracy score with top 4  variable using info and knn : {0:0.4f}'. format(accuracy_score(y_test, y_info_knn)*100))
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_info_knn, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test, y_info_knn, average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_info_knn, average='weighted')))
# Out:
# Model accuracy score with top 4  variable using info and knn : 88.6935
# Precision: 0.8867
# Recall: 0.8869
# F1 Score: 0.8855

# %% [markdown]
# ### RandomForestImportance

# %%
knn_imp=KNeighborsClassifier(n_neighbors=5)
knn_imp.fit(x_train_3,y_train)
y_imp_knn=knn_imp.predict(x_test_3)

# %%
print('Model accuracy score with top 4  variable using importaance and knn : {0:0.4f}'. format(accuracy_score(y_test, y_imp_knn)*100))
print('Precision: {0:0.4f}'.format(precision_score(y_test, y_imp_knn, average='weighted')))
print('Recall: {0:0.4f}'.format(recall_score(y_test, y_imp_knn, average='weighted')))
print('F1 Score: {0:0.4f}'.format(f1_score(y_test, y_imp_knn, average='weighted')))
# Out:
# Model accuracy score with top 4  variable using importaance and knn : 91.9598
# Precision: 0.9192
# Recall: 0.9196
# F1 Score: 0.9190
