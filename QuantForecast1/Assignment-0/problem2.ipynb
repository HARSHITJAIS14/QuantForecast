# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
plotly_google=cv2.imread("/home/harshit/Desktop/QuantForecast/Assignment-0/plotlygoogle.png")
trading_view=cv2.imread("/home/harshit/Desktop/QuantForecast/Assignment-0/Screenshot from 2024-05-08 09-01-58.png")

# %%
type(plotly_google)
# Out:
# numpy.ndarray

# %%
fig=plt.figure(figsize=(35,30))
fig.add_subplot(1,2,1)
plt.imshow(plotly_google)
plt.axis("off")
plt.title("Outcome_problem1")
fig.add_subplot(1,2,2)
plt.imshow(trading_view)
plt.axis("off")
plt.title("trading_view")
# Out:
# Text(0.5, 1.0, 'trading_view')

# %%
#the plots from both the platforms are quite similar to each other and so it can confirm that the data from yfinance and it's plot is good enough for use.
